# %% [markdown]
# <a href="https://colab.research.google.com/github/Jcguedes/08_T22_QUI_N/blob/main/Projeto_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib

# %%
correlacaoCenipa = pd.read_csv("ocorrencias_cenipa.csv", sep=';',encoding='ISO-8859-1')
correlacaoCenipa.head()
# Out:
#    codigo             tipo  ... aeronave_fase_operacao aeronave_nivel_dano
# 0   40107         ACIDENTE  ...                  POUSO                LEVE
# 1   40147         ACIDENTE  ...                  POUSO         SUBSTANCIAL
# 2   40148         ACIDENTE  ...      APROXIMAÇÃO FINAL         SUBSTANCIAL
# 3   40149         ACIDENTE  ...              DECOLAGEM           DESTRUÍDA
# 4   40150  INCIDENTE GRAVE  ...                  POUSO                LEVE
#
# [5 rows x 21 columns]
